# %%
from time import time
import datetime
from operator import itemgetter
import csv

import utils
import data_utils

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import cross_validation as cv
from sklearn.grid_search import RandomizedSearchCV

from scipy.stats import randint as sp_randint

# %%
train, test, test_ids = data_utils.load_transformed_data()
X_train, y_train = data_utils.get_raw_values(train)

# %%
rfr_params = {'n_estimators': 100, 'random_state': 42, 'n_jobs': -1, 'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 6, 'min_samples_split': 40, 'max_features': 13, 'max_depth': 54}
rfr_params = {'n_estimators': 15, 'random_state': 42, 'n_jobs': -1}

# %%
model = RandomForestRegressor(**rfr_params)
folds = cv.KFold(n=len(y_train), n_folds=5, shuffle=True, random_state=42)
scores = cv.cross_val_score(model, X_train, y_train, scoring=utils.rmspe_scorer, cv=folds, n_jobs=-1)
print(scores)
print(scores.mean())
# Out:
# [-0.13866179 -0.25888405 -0.13056529 -0.21951262 -0.14487902]
# -0.178500554819

# %%
train.dtypes
# Out:
# Store                    int64
# DayOfWeek                int64
# Sales                  float64
# Open                     int64
# Promo                    int64
# SchoolHoliday            int64
# woy                      int64
# month                    int64
# Seasonal_4_sin         float64
# StateHoliday_0         float64
# StateHoliday_a         float64
# StateHoliday_b         float64
# StateHoliday_c         float64
# CompetitionDistance    float64
# StoreType_a            float64
# StoreType_b            float64
# StoreType_c            float64
# StoreType_d            float64
# Assortment_a           float64
# Assortment_b           float64
# Assortment_c           float64
# Sales_mean             float64
# dtype: object

# %%
# Utility function to report best scores
def report(grid_scores, n_top=20):
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Model with rank: {0}".format(i + 1))
        print(score.cv_validation_scores)
        print("Mean validation score: {0:.10f} (std: {1:.10f})".format(
              score.mean_validation_score,
              np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        print(score.parameters)
        print("")

# %%
n_features = X_train.shape[1]
model = RandomForestRegressor(n_estimators=15, random_state=42, n_jobs=-1)
# specify parameters and distributions to sample from
param_dist = {"max_depth": sp_randint(1, 3*n_features),
              "max_features": sp_randint(1, n_features),
              "min_samples_split": sp_randint(1, 3*n_features),
              "min_samples_leaf": sp_randint(1, 3*n_features),
              "bootstrap": [True, False],
              "oob_score": [True, False]
             }

# run randomized search
n_iter_search = 120
folds = cv.KFold(n=len(y_train), n_folds=5, shuffle=True, random_state=42)
random_search = RandomizedSearchCV(model,
                                   param_distributions=param_dist,
                                   n_iter=n_iter_search,
                                   cv=folds,
                                   n_jobs=-1,
                                   scoring=utils.rmspe_scorer,
                                   iid=False,
                                   error_score=-99.99
                                  )
start = time()
random_search.fit(X_train, y_train)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))
# Out:
# RandomizedSearchCV took 6203.30 seconds for 120 candidates parameter settings.
# /Library/Python/2.7/site-packages/sklearn/cross_validation.py:1542: FitFailedWarning: Classifier fit failed. The score on this train-test partition for these parameters will be set to -99.990000. Details:
# ValueError('Out of bag estimation only available if bootstrap=True',)
#   "Details: \n%r" % (error_score, e), FitFailedWarning)
# /Library/Python/2.7/site-packages/sklearn/cross_validation.py:1542: FitFailedWarning: Classifier fit failed. The score on this train-test partition for these parameters will be set to -99.990000. Details:
# ValueError('Out of bag estimation only available if bootstrap=True',)
#   "Details: \n%r" % (error_score, e), FitFailedWarning)
# /Library/Python/2.7/site-packages/sklearn/cross_validation.py:1542: FitFailedWarning: Classifier fit failed. The score on this train-test partition for these parameters will be set to -99.990000. Details:
# ...

# %%
report(random_search.grid_scores_)
# Out:
# Model with rank: 1
# [-0.1444515  -0.15934088 -0.11348138 -0.11372803 -0.12519782]
# Mean validation score: -0.1312399203 (std: 0.0180152656)
# Parameters: {'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 6, 'min_samples_split': 40, 'max_features': 13, 'max_depth': 54}
# {'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 6, 'min_samples_split': 40, 'max_features': 13, 'max_depth': 54}
#
# Model with rank: 2
# [-0.15546693 -0.12603342 -0.13571223 -0.24052428 -0.12645563]
# Mean validation score: -0.1568384985 (std: 0.0431823627)
# Parameters: {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 11, 'min_samples_split': 44, 'max_features': 13, 'max_depth': 66}
# {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 11, 'min_samples_split': 44, 'max_features': 13, 'max_depth': 66}
#
# Model with rank: 3
# [-0.18844583 -0.13339544 -0.13829624 -0.24388025 -0.12644235]
# Mean validation score: -0.1660920213 (std: 0.0446418404)
# ...

# %% [raw]
# Model with rank: 1
# [-0.1444515  -0.15934088 -0.11348138 -0.11372803 -0.12519782]
# Mean validation score: -0.1312399203 (std: 0.0180152656)
# Parameters: {'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 6, 'min_samples_split': 40, 'max_features': 13, 'max_depth': 54}
# {'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 6, 'min_samples_split': 40, 'max_features': 13, 'max_depth': 54}
#
# Model with rank: 2
# [-0.15546693 -0.12603342 -0.13571223 -0.24052428 -0.12645563]
# Mean validation score: -0.1568384985 (std: 0.0431823627)
# Parameters: {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 11, 'min_samples_split': 44, 'max_features': 13, 'max_depth': 66}
# {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 11, 'min_samples_split': 44, 'max_features': 13, 'max_depth': 66}
#
# Model with rank: 3
# [-0.18844583 -0.13339544 -0.13829624 -0.24388025 -0.12644235]
# Mean validation score: -0.1660920213 (std: 0.0446418404)
# Parameters: {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 11, 'min_samples_split': 11, 'max_features': 7, 'max_depth': 43}
# {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 11, 'min_samples_split': 11, 'max_features': 7, 'max_depth': 43}
#
# Model with rank: 4
# [-0.14700828 -0.19691697 -0.14729515 -0.17075243 -0.17058599]
# Mean validation score: -0.1665117649 (std: 0.0184863364)
# Parameters: {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 36, 'min_samples_split': 14, 'max_features': 12, 'max_depth': 82}
# {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 36, 'min_samples_split': 14, 'max_features': 12, 'max_depth': 82}
#
# Model with rank: 5
# [-0.14591586 -0.25276047 -0.12692784 -0.16244274 -0.15161018]
# Mean validation score: -0.1679314169 (std: 0.0439510050)
# Parameters: {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 12, 'min_samples_split': 1, 'max_features': 7, 'max_depth': 87}
# {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 12, 'min_samples_split': 1, 'max_features': 7, 'max_depth': 87}
#
# Model with rank: 6
# [-0.14813878 -0.13406722 -0.1427741  -0.24972487 -0.16572611]
# Mean validation score: -0.1680862172 (std: 0.0421101781)
# Parameters: {'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 41, 'min_samples_split': 35, 'max_features': 11, 'max_depth': 75}
# {'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 41, 'min_samples_split': 35, 'max_features': 11, 'max_depth': 75}
#
# Model with rank: 7
# [-0.14175807 -0.18591145 -0.13429347 -0.23542534 -0.16143123]
# Mean validation score: -0.1717639121 (std: 0.0365077492)
# Parameters: {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 5, 'min_samples_split': 38, 'max_features': 20, 'max_depth': 51}
# {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 5, 'min_samples_split': 38, 'max_features': 20, 'max_depth': 51}
#
# Model with rank: 8
# [-0.18940739 -0.13070891 -0.18714551 -0.21893831 -0.14239668]
# Mean validation score: -0.1737193599 (std: 0.0325642113)
# Parameters: {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 3, 'min_samples_split': 39, 'max_features': 5, 'max_depth': 100}
# {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 3, 'min_samples_split': 39, 'max_features': 5, 'max_depth': 100}
#
# Model with rank: 9
# [-0.14456799 -0.22914865 -0.18840978 -0.14456799 -0.16199708]
# Mean validation score: -0.1737382989 (std: 0.0320163383)
# Parameters: {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 52, 'min_samples_split': 48, 'max_features': 13, 'max_depth': 72}
# {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 52, 'min_samples_split': 48, 'max_features': 13, 'max_depth': 72}
#
# Model with rank: 10
# [-0.15171812 -0.17235193 -0.18326127 -0.2020318  -0.16097773]
# Mean validation score: -0.1740681701 (std: 0.0175516784)
# Parameters: {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 49, 'min_samples_split': 43, 'max_features': 13, 'max_depth': 30}
# {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 49, 'min_samples_split': 43, 'max_features': 13, 'max_depth': 30}
#
# Model with rank: 11
# [-0.15352557 -0.18820131 -0.15089349 -0.22282705 -0.16729678]
# Mean validation score: -0.1765488424 (std: 0.0266507834)
# Parameters: {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 13, 'min_samples_split': 9, 'max_features': 18, 'max_depth': 21}
# {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 13, 'min_samples_split': 9, 'max_features': 18, 'max_depth': 21}
#
# Model with rank: 12
# [-0.18452447 -0.15574766 -0.13964733 -0.24278502 -0.16816927]
# Mean validation score: -0.1781747504 (std: 0.0355028217)
# Parameters: {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 16, 'min_samples_split': 17, 'max_features': 18, 'max_depth': 38}
# {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 16, 'min_samples_split': 17, 'max_features': 18, 'max_depth': 38}
#
# Model with rank: 13
# [-0.12827045 -0.2590936  -0.13364281 -0.21809123 -0.15531802]
# Mean validation score: -0.1788832220 (std: 0.0512535646)
# Parameters: {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 39, 'max_features': 19, 'max_depth': 74}
# {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 39, 'max_features': 19, 'max_depth': 74}
#
# Model with rank: 14
# [-0.15654693 -0.21723661 -0.13245481 -0.23097019 -0.16077453]
# Mean validation score: -0.1795966133 (std: 0.0378521382)
# Parameters: {'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 5, 'max_features': 5, 'max_depth': 57}
# {'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 5, 'max_features': 5, 'max_depth': 57}
#
# Model with rank: 15
# [-0.14899643 -0.17836254 -0.16721004 -0.25057118 -0.15367734]
# Mean validation score: -0.1797635060 (std: 0.0368792075)
# Parameters: {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 29, 'min_samples_split': 42, 'max_features': 16, 'max_depth': 82}
# {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 29, 'min_samples_split': 42, 'max_features': 16, 'max_depth': 82}
#
# Model with rank: 16
# [-0.14603631 -0.19650883 -0.19392991 -0.22532503 -0.13808574]
# Mean validation score: -0.1799771648 (std: 0.0329583871)
# Parameters: {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 19, 'min_samples_split': 33, 'max_features': 11, 'max_depth': 72}
# {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 19, 'min_samples_split': 33, 'max_features': 11, 'max_depth': 72}
#
# Model with rank: 17
# [-0.12941838 -0.28228939 -0.1373581  -0.22779995 -0.12879894]
# Mean validation score: -0.1811329526 (std: 0.0628329812)
# Parameters: {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 13, 'min_samples_split': 12, 'max_features': 10, 'max_depth': 21}
# {'oob_score': True, 'bootstrap': True, 'min_samples_leaf': 13, 'min_samples_split': 12, 'max_features': 10, 'max_depth': 21}
#
# Model with rank: 18
# [-0.148086   -0.2501797  -0.1699779  -0.18722922 -0.15121203]
# Mean validation score: -0.1813369685 (std: 0.0371919529)
# Parameters: {'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 51, 'min_samples_split': 33, 'max_features': 19, 'max_depth': 42}
# {'oob_score': False, 'bootstrap': False, 'min_samples_leaf': 51, 'min_samples_split': 33, 'max_features': 19, 'max_depth': 42}
#
# Model with rank: 19
# [-0.14545535 -0.25808385 -0.21569749 -0.14007935 -0.14982677]
# Mean validation score: -0.1818285623 (std: 0.0470150936)
# Parameters: {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 18, 'min_samples_split': 35, 'max_features': 13, 'max_depth': 43}
# {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 18, 'min_samples_split': 35, 'max_features': 13, 'max_depth': 43}
#
# Model with rank: 20
# [-0.18405427 -0.25386088 -0.12205831 -0.22892646 -0.12239402]
# Mean validation score: -0.1822587909 (std: 0.0538810608)
# Parameters: {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 9, 'min_samples_split': 4, 'max_features': 7, 'max_depth': 48}
# {'oob_score': False, 'bootstrap': True, 'min_samples_leaf': 9, 'min_samples_split': 4, 'max_features': 7, 'max_depth': 48}
